# %%
#https://medium.com/nerd-for-tech/building-an-object-detector-in-tensorflow-using-bounding-box-regression-2bc13992973f
#https://www.pyimagesearch.com/2020/10/12/multi-class-object-detection-and-bounding-box-regression-with-keras-tensorflow-and-deep-learning/
import json
import numpy as np
import os
import PIL
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from keras.preprocessing import image
import pathlib
import pandas as pd
from PIL import Image 
from PIL.ImageDraw import Draw
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.patches import Rectangle
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
categories = ['with_mask', 'without_mask']

f = open ('annotations.json', "r")

data = json.loads(f.read())

images  = []    # Les images d'origine
#images_boxes = [] # Les images selectionnées 
targets = []    # Les coordonnées des boxes 
labels  = []    # Les catégories des boxes  
filenames = []  # Les chemins des images
#test_filenames = []



width = 180
height = 180
num_classes = len(categories)

# %%
# Récupérer les données depuis le json (ie les informations sur les boxes)
def load_data():
    global images, targets, labels, filenames, test_filenames,images_boxes
    
    images = []
    targets = []
    labels = []
    filenames = []
    #images_boxes = []
    #test_filenames = []


    for i in data['data']:
        path = i['image']['path']
        we, he = Image.open(path).size # largeur et hauteur de l'image d'origine
        img = image.load_img(path,target_size=(width,height)) #L'image d'origine en taille 180/180
        img_arr = image.img_to_array(img)
        #img_arr = tf.expand_dims(img, axis=0)

        for j in i['image']['boxes']:  # On regarde les boxes correspondantes à l'image d'origine
            if(len(j)!=1):
                w = int(j['width'])
                h = int(j['height'])
                               
                category = j['category']
                
                name = j['name'].split('-')
                
                coords = name[1].split('x')
                xmin = float(coords[0].split('bb')[1]) 
                ymin = float(coords[1]) 
                xmax = float(xmin + w)  
                ymax = float(ymin + h)   

                path_box = ".."+j['path']
                
                '''
                # à modifier
                index = path_box.find('bb')
                pathb = path_box[0:index]+'bb-'+path_box[index+2:]
                
                width_box, height_box = Image.open(pathb).size
                image_selected = image.load_img(pathb,target_size=(width_box,height_box))
                image_selected_arr = image.img_to_array(image_selected)
                '''
                              
                images = images + [img_arr]
                x = (xmin/we, ymin/he, xmax/we, ymax/he) # on réduit les coordonées à l'intervalle [0,1]
                targets = targets + [x]
                labels = labels + [categories.index(category)]
                filenames.append(path)
                #test_filenames.append(pathb)
                #images_boxes.append(image_selected_arr)



load_data()
#print(images)
#print(targets)
#print(labels)
#print(filenames)
#print(test_filenames)

# %%
train_images =  np.array(images[0:40]+images[50:90])
train_targets = np.array(targets[0:40]+targets[50:90])
train_labels =  np.array(labels[0:40]+labels[50:90])
train_filenames = np.array(filenames[0:40]+filenames[50:90])

validation_images =  np.array(images[40:50]+images[90:])
validation_targets = np.array(targets[40:50]+targets[90:])
validation_labels =  np.array(labels[40:50]+labels[90:])
validation_filenames = np.array(filenames[40:50]+filenames[90:])
#validation_images_box = np.array(images_boxes[40:50]+images_boxes[90:])
#validation_images_filenames = np.array(test_filenames[40:50]+test_filenames[90:])

train_images, validation_images, train_targets, validation_targets,train_labels,validation_labels,train_filenames,validation_filenames = train_test_split(images, targets,labels,filenames, test_size=0.20, random_state=42,shuffle=True)
train_images = np.array(train_images)
train_targets = np.array(train_targets)
train_labels = np.array(train_labels)
train_filenames = np.array(train_filenames)

validation_images = np.array(validation_images)
validation_targets = np.array(validation_targets)
validation_labels = np.array(validation_labels)
validation_filenames = np.array(validation_filenames)

#print(validation_filenames)
# Out:
# ['../img/resized/without_mask/image83.png'
#  '../img/resized/without_mask/image53.png'
#  '../img/resized/without_mask/image70.png'
#  '../img/resized/with_mask/image5.png'
#  '../img/resized/with_mask/image49.png'
#  '../img/resized/with_mask/image44.png'
#  '../img/resized/with_mask/image29.png'
#  '../img/resized/without_mask/image80.png'
#  '../img/resized/with_mask/image18.png'
#  '../img/resized/with_mask/image0.png'
#  '../img/resized/with_mask/image25.png'
#  '../img/resized/with_mask/image36.png'
#  '../img/resized/without_mask/image73.png'
#  '../img/resized/with_mask/image39.png'
#  '../img/resized/without_mask/image90.png'
#  '../img/resized/with_mask/image12.png'
#  '../img/resized/without_mask/image76.png'
#  '../img/resized/without_mask/image77.png'
#  '../img/resized/with_mask/image2.png'
#  '../img/resized/with_mask/image37.png']

# %%
input_shape = (height, width, 3)
input_layer = tf.keras.layers.Input(input_shape)
#create the base layers

base_layers = layers.experimental.preprocessing.Rescaling(1./255, name='bl_1')(input_layer)
base_layers = layers.Conv2D(16, 3, padding='same', activation='relu', name='bl_2')(base_layers)
base_layers = layers.MaxPooling2D(name='bl_3')(base_layers)
base_layers = layers.Conv2D(32, 3, padding='same', activation='relu', name='bl_4')(base_layers)
base_layers = layers.MaxPooling2D(name='bl_5')(base_layers)
base_layers = layers.Conv2D(64, 3, padding='same', activation='relu', name='bl_6')(base_layers)
base_layers = layers.MaxPooling2D(name='bl_7')(base_layers)
base_layers = layers.Flatten(name='bl_8')(base_layers)


classifier_branch = layers.Dense(128, activation='relu', name='cl_1')(base_layers)
classifier_branch = layers.Dense(num_classes, name='cl_head')(classifier_branch)  

locator_branch = layers.Dense(128, activation='relu', name='bb_1')(base_layers)
locator_branch = layers.Dense(64, activation='relu', name='bb_2')(locator_branch)
locator_branch = layers.Dense(32, activation='relu', name='bb_3')(locator_branch)
locator_branch = layers.Dense(4, activation='sigmoid', name='bb_head')(locator_branch)

model = tf.keras.Model(input_layer,
           outputs=[classifier_branch,locator_branch])


losses = {"cl_head":tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), "bb_head":tf.keras.losses.MSE}
    
model.compile(loss=losses, optimizer='Adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 180, 180, 3  0           []
#                                 )]
#
#  bl_1 (Rescaling)               (None, 180, 180, 3)  0           ['input_1[0][0]']
#
#  bl_2 (Conv2D)                  (None, 180, 180, 16  448         ['bl_1[0][0]']
#                                 )
#
#  bl_3 (MaxPooling2D)            (None, 90, 90, 16)   0           ['bl_2[0][0]']
#
#  bl_4 (Conv2D)                  (None, 90, 90, 32)   4640        ['bl_3[0][0]']
#
#  bl_5 (MaxPooling2D)            (None, 45, 45, 32)   0           ['bl_4[0][0]']
#
#  bl_6 (Conv2D)                  (None, 45, 45, 64)   18496       ['bl_5[0][0]']
#
#  bl_7 (MaxPooling2D)            (None, 22, 22, 64)   0           ['bl_6[0][0]']
#
#  bl_8 (Flatten)                 (None, 30976)        0           ['bl_7[0][0]']
#
#  bb_1 (Dense)                   (None, 128)          3965056     ['bl_8[0][0]']
#
#  bb_2 (Dense)                   (None, 64)           8256        ['bb_1[0][0]']
#
#  cl_1 (Dense)                   (None, 128)          3965056     ['bl_8[0][0]']
#
#  bb_3 (Dense)                   (None, 32)           2080        ['bb_2[0][0]']
#
#  cl_head (Dense)                (None, 2)            258         ['cl_1[0][0]']
#
#  bb_head (Dense)                (None, 4)            132         ['bb_3[0][0]']
#
# ==================================================================================================
# Total params: 7,964,422
# Trainable params: 7,964,422
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
trainTargets = {
    "cl_head": train_labels,
    "bb_head": train_targets
}
validationTargets = {
    "cl_head": validation_labels,
    "bb_head": validation_targets
}

history = model.fit(train_images, trainTargets,
             validation_data=(validation_images, validationTargets),
             batch_size=32,
             epochs=100,
             shuffle=True,
             verbose=1)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 4s 960ms/step - loss: 0.9430 - cl_head_loss: 0.8744 - bb_head_loss: 0.0685 - cl_head_accuracy: 0.5000 - bb_head_accuracy: 0.3500 - val_loss: 0.7567 - val_cl_head_loss: 0.7301 - val_bb_head_loss: 0.0266 - val_cl_head_accuracy: 0.4500 - val_bb_head_accuracy: 0.6000
# Epoch 2/100
# 3/3 [==============================] - 2s 690ms/step - loss: 0.7302 - cl_head_loss: 0.6894 - bb_head_loss: 0.0408 - cl_head_accuracy: 0.6250 - bb_head_accuracy: 0.5500 - val_loss: 0.7141 - val_cl_head_loss: 0.6872 - val_bb_head_loss: 0.0268 - val_cl_head_accuracy: 0.6000 - val_bb_head_accuracy: 0.6000
# Epoch 3/100
# 3/3 [==============================] - 2s 710ms/step - loss: 0.6845 - cl_head_loss: 0.6449 - bb_head_loss: 0.0396 - cl_head_accuracy: 0.5000 - bb_head_accuracy: 0.5500 - val_loss: 0.7636 - val_cl_head_loss: 0.7324 - val_bb_head_loss: 0.0313 - val_cl_head_accuracy: 0.4000 - val_bb_head_accuracy: 0.6000
# Epoch 4/100
# 3/3 [==============================] - 2s 709ms/step - loss: 0.5937 - cl_head_loss: 0.5543 - bb_head_loss: 0.0394 - cl_head_accuracy: 0.7625 - bb_head_accuracy: 0.5500 - val_loss: 0.6756 - val_cl_head_loss: 0.6497 - val_bb_head_loss: 0.0260 - val_cl_head_accuracy: 0.6000 - val_bb_head_accuracy: 0.6000
# Epoch 5/100
# 3/3 [==============================] - 2s 674ms/step - loss: 0.4529 - cl_head_loss: 0.4205 - bb_head_loss: 0.0324 - cl_head_accuracy: 0.9625 - bb_head_accuracy: 0.5500 - val_loss: 0.6419 - val_cl_head_loss: 0.6201 - val_bb_head_loss: 0.0218 - val_cl_head_accuracy: 0.5500 - val_bb_head_accuracy: 0.6000
# Epoch 6/100
# 3/3 [==============================] - 2s 702ms/step - loss: 0.3467 - cl_head_loss: 0.3177 - bb_head_loss: 0.0289 - cl_head_accuracy: 0.9000 - bb_head_accuracy: 0.5500 - val_loss: 0.6618 - val_cl_head_loss: 0.6423 - val_bb_head_loss: 0.0196 - val_cl_head_accuracy: 0.5500 - val_bb_head_accuracy: 0.6000
# Epoch 7/100
# 3/3 [==============================] - 2s 670ms/step - loss: 0.2711 - cl_head_loss: 0.2513 - bb_head_loss: 0.0198 - cl_head_accuracy: 0.9500 - bb_head_accuracy: 0.6000 - val_loss: 0.7361 - val_cl_head_loss: 0.7199 - val_bb_head_loss: 0.0162 - val_cl_head_accuracy: 0.5500 - val_bb_head_accuracy: 0.6500
# Epoch 8/100
# 3/3 [==============================] - 2s 767ms/step - loss: 0.1610 - cl_head_loss: 0.1446 - bb_head_loss: 0.0164 - cl_head_accuracy: 0.9750 - bb_head_accuracy: 0.6625 - val_loss: 0.9231 - val_cl_head_loss: 0.9046 - val_bb_head_loss: 0.0185 - val_cl_head_accuracy: 0.6000 - val_bb_head_accuracy: 0.6500
# Epoch
-04 - cl_head_accuracy: 1.0000 - bb_head_accuracy: 0.9875 - val_loss: 1.8089 - val_cl_head_loss: 1.7940 - val_bb_head_loss: 0.0149 - val_cl_head_accuracy: 0.6500 - val_bb_head_accuracy: 0.7000
# Epoch 92/100
# 3/3 [==============================] - 2s 815ms/step - loss: 2.1512e-04 - cl_head_loss: 2.7483e-05 - bb_head_loss: 1.8764e-04 - cl_head_accuracy: 1.0000 - bb_head_accuracy: 0.9750 - val_loss: 1.8094 - val_cl_head_loss: 1.7948 - val_bb_head_loss: 0.0145 - val_cl_head_accuracy: 0.6000 - val_bb_head_accuracy: 0.6500
# Epoch 93/100
# 3/3 [==============================] - 2s 705ms/step - loss: 2.1505e-04 - cl_head_loss: 2.8015e-05 - bb_head_loss: 1.8703e-04 - cl_head_accuracy: 1.0000 - bb_head_accuracy: 1.0000 - val_loss: 1.8101 - val_cl_head_loss: 1.7956 - val_bb_head_loss: 0.0146 - val_cl_head_accuracy: 0.6000 - val_bb_head_accuracy: 0.7000
# Epoch 94/100
# 3/3 [==============================] - 2s 709ms/step - loss: 1.5180e-04 - cl_head_loss: 2.7673e-05 - bb_head_loss: 1.2413e-04 - cl_head_accuracy: 1.0000 - bb_head_accuracy: 0.9875 - val_loss: 1.8002 - val_cl_head_loss: 1.7860 - val_bb_head_loss: 0.0142 - val_cl_head_accuracy: 0.6500 - val_bb_head_accuracy: 0.6500
# Epoch 95/100
# 3/3 [==============================] - 2s 681ms/step - loss: 1.6330e-04 - cl_head_loss: 2.7152e-05 - bb_head_loss: 1.3614e-04 - cl_head_accuracy: 1.0000 - bb_head_accuracy: 1.0000 - val_loss: 1.8049 - val_cl_head_loss: 1.7905 - val_bb_head_loss: 0.0145 - val_cl_head_accuracy: 0.6500 - val_bb_head_accuracy: 0.6500
# Epoch 96/100
# 3/3 [==============================] - 2s 714ms/step - loss: 1.9559e-04 - cl_head_loss: 2.7069e-05 - bb_head_loss: 1.6853e-04 - cl_head_accuracy: 1.0000 - bb_head_accuracy: 1.0000 - val_loss: 1.7990 - val_cl_head_loss: 1.7850 - val_bb_head_loss: 0.0140 - val_cl_head_accuracy: 0.6500 - val_bb_head_accuracy: 0.6500
# Epoch 97/100
# 3/3 [==============================] - 2s 784ms/step - loss: 2.0407e-04 - cl_head_loss: 2.6306e-05 - bb_head_loss: 1.7776e-04 - cl_head_accuracy: 1.0000 - bb_head_accuracy: 0.9875 - val_loss: 1.8151 - val_cl_head_loss: 1.8004 - val_bb_head_loss: 0.0147 - val_cl_head_accuracy: 0.6000 - val_bb_head_accuracy: 0.6500
# Epoch 98/100
# 3/3 [==============================] - 2s 660ms/step - loss: 1.9046e-04 - cl_head_loss: 2.6586e-05 - bb_head_loss: 1.6387e-04 - cl_head_accuracy: 1.0000 - bb_head_accuracy: 0.9750 - val_loss: 1.8144 - val_cl_head_loss: 1.7996 - val_bb_head_loss: 0.0148 - val_cl_head_accuracy: 0.6000 - val_bb_head_accuracy: 0.6500
# Epoch 99/100
# 3/3 [==============================] - 2s 696ms/step - loss: 2.4627e-04 - cl_head_loss: 2.6629e-05 - bb_head_loss: 2.1964e-04 - cl_head_accuracy: 1.0000 - bb_head_accuracy: 1.0000 - val_loss: 1.8151 - val_cl_head_loss: 1.8005 - val_bb_head_loss: 0.0146 - val_cl_head_accuracy: 0.6000 - val_bb_head_accuracy: 0.6500
# Epoch 100/100
# 3/3 [==============================] - 2s 718ms/step - loss: 2.0508e-04 - cl_head_loss: 2.6866e-05 - bb_head_loss: 1.7821e-04 - cl_head_accuracy: 1.0000 - bb_head_accuracy: 0.9750 - val_loss: 1.8033 - val_cl_head_loss: 1.7891 - val_bb_head_loss: 0.0142 - val_cl_head_accuracy: 0.6500 - val_bb_head_accuracy: 0.6500

# %%
def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()

plot_graphs(history, "bb_head_accuracy")
plot_graphs(history, "cl_head_accuracy")
plot_graphs(history, "loss")

# %%
predictions = model.predict(validation_images)
predicted_labels = []
#print(predictions)

accuracy = 0

for nb_image in range(len(validation_images)):
    
    fig, ax = plt.subplots()

    img = Image.open(validation_filenames[nb_image]) # On ouvre l'image avec sa taille originale
    print(validation_filenames[nb_image])
    we, he = img.size  # largeur et hauteur de l'image initiale
    ax.imshow(img) # on affiche l'image
    
    classes_predcitions = predictions[0][nb_image] # les prédictions des classes
    boxes_predictions = predictions[1][nb_image] # les prédictions des boites
    
    # On repasse des coordonnées dans [0,1] aux coordonnées dans [largeur image, hauteur image] 
    xmin = boxes_predictions[0] * we 
    ymin = boxes_predictions[1] * he
    xmax = boxes_predictions[2] * we 
    ymax = boxes_predictions[3] * he
    
    w = abs(xmax-xmin) # largeur de la boite
    h = abs(ymax-ymin) # hauteur de la boite
    
    # determination de la categorie : 
    probas = tf.nn.softmax(classes_predcitions)
    pourcentage = int(round(100*np.max(probas), 0))
    category_predicted = categories[np.argmax(probas)] 
    
    predicted_labels.append(np.argmax(probas))

    print(category_predicted, pourcentage, "%")
    
        
    if (np.argmax(probas) == validation_labels[nb_image]):
        accuracy = accuracy + 1

    ax.add_patch(Rectangle((xmin,ymin), w, h,linewidth=1,edgecolor='r',facecolor='none')) # le dessin de la boite
    
    plt.axis('off')  # si on veut enlever les graduations des axes
    plt.show()
    
print("Accuracy : ", accuracy/len(validation_images) )
print("Matrice de confusion :")
print(metrics.confusion_matrix(validation_labels, predicted_labels))
print(metrics.classification_report(validation_labels, predicted_labels,target_names=categories))
# Out:
# ../img/resized/without_mask/image83.png
# without_mask 99 %
# ../img/resized/without_mask/image53.png
# with_mask 96 %
# ../img/resized/without_mask/image70.png
# without_mask 100 %
# ../img/resized/with_mask/image5.png
# without_mask 99 %
# ../img/resized/with_mask/image49.png
# with_mask 100 %
# ../img/resized/with_mask/image44.png
# with_mask 98 %
# ../img/resized/with_mask/image29.png
# with_mask 99 %
# ../img/resized/without_mask/image80.png
# without_mask 100 %
# ../img/resized/with_mask/image18.png
# without_mask 100 %
# ../img/resized/with_mask/image0.png
# without_mask 100 %
# ../img/resized/with_mask/image25.png
# without_mask 99 %
# ../img/resized/with_mask/image36.png
# without_mask 98 %
# ../img/resized/without_mask/image73.png
# with_mask 71 %
# ../img/resized/with_mask/image39.png
# with_mask 100 %
# ../img/resized/without_mask/image90.png
# without_mask 100 %
# ../img/resized/with_mask/image12.png
# with_mask 100 %
# ../img/resized/without_mask/image76.png
# without_mask 77 %
# ../img/resized/without_mask/image77.png
# without_mask 87 %
# ../img/resized/with_mask/image2.png
# with_mask 100 %
# ../img/resized/with_mask/image37.png
# with_mask 50 %
# Accuracy :  0.65
# Matrice de confusion :
# [[7 5]
#  [2 6]]
#               precision    recall  f1-score   support
#
#    with_mask       0.78      0.58      0.67        12
# without_mask       0.55      0.75      0.63         8
#
#     accuracy                           0.65        20
#    macro avg       0.66      0.67      0.65        20
# weighted avg       0.68      0.65      0.65        20

# %%
def prediction_function(file, mode):
    
    try:
        nb_image = list(validation_filenames).index(file)
        predictions = model.predict(validation_images)
      
        if mode=='category':
            category_predicted = categories[np.argmax(tf.nn.softmax(predictions[0][nb_image]))]
            print(" The predicted category is :  ", category_predicted )

        elif mode=='probabilities':
            proba_with_mask = int(round(100*np.max((tf.nn.softmax(predictions[0][nb_image]))[0]),0))
            proba_without_mask =  int(round(100*np.max((tf.nn.softmax(predictions[0][nb_image]))[1]),0))

            print(" Probability for the category with_mask     : " , proba_with_mask , "%")
            print(" Probability for the category without_mask  : " , proba_without_mask ,"%")
            

    except ValueError:
        print("Warning : the file name or the mode name contains an error.")
        
prediction_function("../img/resized/without_mask/image99.png","probabilities")
# Out:
# Warning : the file name or the mode name contains an error.
