# %%
#https://medium.com/nerd-for-tech/building-an-object-detector-in-tensorflow-using-bounding-box-regression-2bc13992973f

import json
import numpy as np
import os
import PIL
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from keras.preprocessing import image
import pathlib
import pandas as pd
from PIL import Image 
from PIL.ImageDraw import Draw
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.patches import Rectangle
from sklearn.model_selection import train_test_split

# %%
categories = ['with_mask', 'without_mask']

f = open ('annotations.json', "r")

data = json.loads(f.read())

images  = []    # Les images d'origine
targets = []    # Les coordonnées des boxes 
labels  = []    # Les catégories des boxes  
filenames = []  # Les chemins des images


width = 180
height = 180
num_classes = len(categories)

# %%
# Récupérer les données depuis le json (ie les informations sur les boxes)
def load_data():
    global images, targets, labels, filenames 
    
    images = []
    targets = []
    labels = []
    filenames = []

    for i in data['data']:
        path = i['image']['path']
        we, he = Image.open(path).size # largeur et hauteur de l'image d'origine
        img = image.load_img(path,target_size=(height,width)) #L'image d'origine en taille 180/180
        img_arr = image.img_to_array(img)
        #img_arr = tf.expand_dims(img, axis=0)

        for j in i['image']['boxes']:  # On regarde les boxes correspondantes à l'image d'origine
            if(len(j)!=1):
                w = int(j['width'])
                h = int(j['height'])
                               
                category = j['category']
                
                name = j['name'].split('-')
                
                coords = name[1].split('x')
                xmin = float(coords[0].split('bb')[1]) 
                ymin = float(coords[1]) 
                xmax = float(xmin + w)  
                ymax = float(ymin + h)   

                              
                images = images + [img_arr]
                x = (xmin/we, ymin/he, xmax/we, ymax/he) # on réduit les coordonées à l'intervalle [0,1]
                targets = targets + [x]
                labels = labels + [categories.index(category)]
                filenames.append(path)



load_data()
#print(images)
#print(targets)
#print(labels)
#print(filenames)

# %%
# Si on veut transformer en np array : 
train_images =  np.array(images[0:40]+images[50:90])
train_targets = np.array(targets[0:40]+targets[50:90])
train_labels =  np.array(labels[0:40]+labels[50:90])
train_filenames = np.array(filenames[0:40]+filenames[50:90])

validation_images =  np.array(images[40:50]+images[90:])
validation_targets = np.array(targets[40:50]+targets[90:])
validation_labels =  np.array(labels[40:50]+labels[90:])
validation_filenames = np.array(filenames[40:50]+filenames[90:])

input_shape = (height, width, 3)
input_layer = tf.keras.layers.Input(input_shape)
#create the base layers

base_layers = layers.experimental.preprocessing.Rescaling(1./255, name='bl_1')(input_layer)
base_layers = layers.Conv2D(16, 3, padding='same', activation='relu', name='bl_2')(base_layers)
base_layers = layers.MaxPooling2D(name='bl_3')(base_layers)
base_layers = layers.Conv2D(32, 3, padding='same', activation='relu', name='bl_4')(base_layers)
base_layers = layers.MaxPooling2D(name='bl_5')(base_layers)
base_layers = layers.Conv2D(64, 3, padding='same', activation='relu', name='bl_6')(base_layers)
base_layers = layers.MaxPooling2D(name='bl_7')(base_layers)
base_layers = layers.Flatten(name='bl_8')(base_layers)


classifier_branch = layers.Dense(128, activation='relu', name='cl_1')(base_layers)
classifier_branch = layers.Dense(num_classes, name='cl_head')(classifier_branch)  

locator_branch = layers.Dense(128, activation='relu', name='bb_1')(base_layers)
locator_branch = layers.Dense(64, activation='relu', name='bb_2')(locator_branch)
locator_branch = layers.Dense(32, activation='relu', name='bb_3')(locator_branch)
locator_branch = layers.Dense(4, activation='sigmoid', name='bb_head')(locator_branch)

model = tf.keras.Model(input_layer,
           outputs=[classifier_branch,locator_branch])


losses = {"cl_head":tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), "bb_head":tf.keras.losses.MSE}
    
model.compile(loss=losses, optimizer='Adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 180, 180, 3  0           []
#                                 )]
#
#  bl_1 (Rescaling)               (None, 180, 180, 3)  0           ['input_2[0][0]']
#
#  bl_2 (Conv2D)                  (None, 180, 180, 16  448         ['bl_1[0][0]']
#                                 )
#
#  bl_3 (MaxPooling2D)            (None, 90, 90, 16)   0           ['bl_2[0][0]']
#
#  bl_4 (Conv2D)                  (None, 90, 90, 32)   4640        ['bl_3[0][0]']
#
#  bl_5 (MaxPooling2D)            (None, 45, 45, 32)   0           ['bl_4[0][0]']
#
#  bl_6 (Conv2D)                  (None, 45, 45, 64)   18496       ['bl_5[0][0]']
#
#  bl_7 (MaxPooling2D)            (None, 22, 22, 64)   0           ['bl_6[0][0]']
#
#  bl_8 (Flatten)                 (None, 30976)        0           ['bl_7[0][0]']
#
#  bb_1 (Dense)                   (None, 128)          3965056     ['bl_8[0][0]']
#
#  bb_2 (Dense)                   (None, 64)           8256        ['bb_1[0][0]']
#
#  cl_1 (Dense)                   (None, 128)          3965056     ['bl_8[0][0]']
#
#  bb_3 (Dense)                   (None, 32)           2080        ['bb_2[0][0]']
#
#  cl_head (Dense)                (None, 2)            258         ['cl_1[0][0]']
#
#  bb_head (Dense)                (None, 4)            132         ['bb_3[0][0]']
#
# ==================================================================================================
# Total params: 7,964,422
# Trainable params: 7,964,422
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
trainTargets = {
    "cl_head": train_labels,
    "bb_head": train_targets
}
validationTargets = {
    "cl_head": validation_labels,
    "bb_head": validation_targets
}

history = model.fit(train_images, trainTargets,
             validation_data=(validation_images, validationTargets),
             batch_size=4,
             epochs=20,
             shuffle=True,
             verbose=1)
# Out:
# Epoch 1/20
# 20/20 [==============================] - 5s 160ms/step - loss: 1.0512 - cl_head_loss: 0.9992 - bb_head_loss: 0.0520 - cl_head_accuracy: 0.4375 - bb_head_accuracy: 0.6000 - val_loss: 0.7527 - val_cl_head_loss: 0.6902 - val_bb_head_loss: 0.0625 - val_cl_head_accuracy: 0.5263 - val_bb_head_accuracy: 0.5263
# Epoch 2/20
# 20/20 [==============================] - 3s 138ms/step - loss: 0.7173 - cl_head_loss: 0.6816 - bb_head_loss: 0.0357 - cl_head_accuracy: 0.6250 - bb_head_accuracy: 0.6250 - val_loss: 0.7213 - val_cl_head_loss: 0.6798 - val_bb_head_loss: 0.0416 - val_cl_head_accuracy: 0.5263 - val_bb_head_accuracy: 0.5263
# Epoch 3/20
# 20/20 [==============================] - 3s 137ms/step - loss: 0.6851 - cl_head_loss: 0.6517 - bb_head_loss: 0.0333 - cl_head_accuracy: 0.6875 - bb_head_accuracy: 0.7000 - val_loss: 0.7131 - val_cl_head_loss: 0.6597 - val_bb_head_loss: 0.0534 - val_cl_head_accuracy: 0.7368 - val_bb_head_accuracy: 0.7368
# Epoch 4/20
# 20/20 [==============================] - 3s 138ms/step - loss: 0.5759 - cl_head_loss: 0.5471 - bb_head_loss: 0.0288 - cl_head_accuracy: 0.7500 - bb_head_accuracy: 0.7750 - val_loss: 0.6498 - val_cl_head_loss: 0.6062 - val_bb_head_loss: 0.0436 - val_cl_head_accuracy: 0.6316 - val_bb_head_accuracy: 0.5263
# Epoch 5/20
# 20/20 [==============================] - 3s 147ms/step - loss: 0.4250 - cl_head_loss: 0.4007 - bb_head_loss: 0.0243 - cl_head_accuracy: 0.8500 - bb_head_accuracy: 0.7125 - val_loss: 0.6229 - val_cl_head_loss: 0.5824 - val_bb_head_loss: 0.0404 - val_cl_head_accuracy: 0.6316 - val_bb_head_accuracy: 0.5263
# Epoch 6/20
# 20/20 [==============================] - 3s 138ms/step - loss: 0.2910 - cl_head_loss: 0.2740 - bb_head_loss: 0.0170 - cl_head_accuracy: 0.9125 - bb_head_accuracy: 0.7750 - val_loss: 0.7344 - val_cl_head_loss: 0.7009 - val_bb_head_loss: 0.0335 - val_cl_head_accuracy: 0.6316 - val_bb_head_accuracy: 0.8421
# Epoch 7/20
# 20/20 [==============================] - 3s 141ms/step - loss: 0.1244 - cl_head_loss: 0.1119 - bb_head_loss: 0.0124 - cl_head_accuracy: 0.9750 - bb_head_accuracy: 0.7875 - val_loss: 0.6277 - val_cl_head_loss: 0.5925 - val_bb_head_loss: 0.0351 - val_cl_head_accuracy: 0.7368 - val_bb_head_accuracy: 0.5263
# Epoch 8/20
# 20/20 [==============================] - 3s 140ms/step - loss: 0.0485 - cl_head_loss: 0.0392 - bb_head_loss: 0.0092 - cl_head_accuracy: 0.9875 - bb_head_accuracy: 0.7125 - val_loss: 0.9079 - val_cl_head_loss: 0.8763 - val_bb_head_loss: 0.0316 - val_cl_head_accuracy: 0.7368 - val_bb_head_accuracy: 0.7368
# Epoch 9/20
# 20/20 [==============================] - 3s 147ms/step - loss: 0.0177 - cl_head_loss: 0.0117 - bb_head_loss: 0.0060 - cl_head_accuracy: 1.0000 - bb_head_accuracy: 0.7625 - val_loss: 0.7908 - val_cl_head_loss: 0.7554 - val_bb_head_loss: 0.0354 - val_cl_head_accuracy: 0.7368 - val_bb_head_accuracy: 0.6842
# Epoch 10/20
# 20/20 [==============================] - 3s 141ms/step - loss: 0.0090 - cl_head_loss: 0.0052 - bb_head_loss: 0.0039 - cl_head_accuracy: 1.0000 - bb_head_accuracy: 0.8625 - val_loss: 0.6971 - val_cl_head_loss: 0.6607 - val_bb_head_loss: 0.0363 - val_cl_head_accuracy: 0.8421 - val_bb_head_accuracy: 0.6842
# Epoch 11/20
# 20/20 [==============================] - 3s 150ms/step - loss: 0.0035 - cl_head_loss: 0.0011 - bb_head_loss: 0.0024 - cl_head_accuracy: 1.0000 - bb_head_accuracy: 0.9125 - val_loss: 0.7924 - val_cl_head_loss: 0.7590 - val_bb_head_loss: 0.0334 - val_cl_head_accuracy: 0.8421 - val_bb_head_accuracy: 0.8421
# Epoch 12/20
# 20/20 [==============================] - 3s 139ms/step - loss: 0.0024 - cl_head_loss: 5.7200e-04 - bb_head_loss: 0.0018 - cl_head_accuracy: 1.0000 - bb_head_accuracy: 0.9250 - val_loss: 0.8042 - val_cl_head_loss: 0.7716 - val_bb_head_loss: 0.0326 - val_cl_head_accuracy: 0.8421 - val_bb_head_accuracy: 0.7368
# Epoch 13/20
# 20/20 [==============================] - 3s 137ms/step - loss: 0.0019 - cl_head_loss: 4.4785e-04 - bb_head_loss: 0.0015 - cl_head_accuracy: 1.0000 - bb_head_accuracy: 0.9625 - val_loss: 0.8089 - val_cl_head_loss: 0.7760 - val_bb_head_loss: 0.0329 - val_cl_head_accuracy: 0.8421 - val_bb_head_accuracy: 0.8421
# Epoch 14/20
# 20/20 [==============================] - 3s 141ms/step - loss: 0.0021 - cl_head_loss: 3.4501e-04 - bb_head_loss: 0.0017 - cl_head_accuracy: 1.0000 - bb_head_accuracy: 0.9375 - val_loss: 0.8165 - val_cl_head_loss: 0.7804 - val_bb_head_loss: 0.0360 - val_cl_head_accuracy: 0.8421 - val_bb_head_accuracy: 0.7368
# Epoch 15/20
# 20/20 [==============================] - 3s 146ms/step - loss: 0.0021 - cl_head_loss: 3.3224e-04 - bb_head_loss: 0.0018 - cl_head_accuracy: 1.0000 - bb_head_accuracy: 0.9625 - val_loss: 0.8025 - val_cl_head_loss: 0.7693 - val_bb_head_loss: 0.0332 - val_cl_head_accuracy: 0.8421 - val_bb_head_accuracy: 0.7895
# Epoch 16/20
# 20/20 [==============================] - 3s 166ms/step - loss: 0.0018 - cl_head_loss: 3.1403e-04 - bb_head_loss: 0.0015 - cl_head_accuracy: 1.0000 - bb_head_accuracy: 0.9125 - val_loss: 0.8082 - val_cl_head_loss: 0.7720 - val_bb_head_loss: 0.0362 - val_cl_head_accuracy: 0.8421 - val_bb_head_accuracy: 0.7895
# Epoch 17/20
# 20/20 [==============================] - 3s 163ms/step - loss: 0.0016 - cl_head_loss: 2.9352e-04 - bb_head_loss: 0.0013 - cl_head_accuracy: 1.0000 - bb_head_accuracy: 0.9625 - val_loss: 0.7987 - val_cl_head_loss: 0.7682 - val_bb_head_loss: 0.0305 - val_cl_head_accuracy: 0.8421 - val_bb_head_accuracy: 0.7368
# Epoch 18/20
# 20/20 [==============================] - 3s 161ms/step - loss: 0.0018 - cl_head_loss: 2.8937e-04 - bb_head_loss: 0.0015 - cl_head_accuracy: 1.0000 - bb_head_accuracy: 0.9625 - val_loss: 0.7997 - val_cl_head_loss: 0.7643 - val_bb_head_loss: 0.0354 - val_cl_head_accuracy: 0.8421 - val_bb_head_accuracy: 0.7368
# Epoch 19/20
# 20/20 [==============================] - 3s 171ms/step - loss: 0.0022 - cl_head_loss: 2.7400e-04 - bb_head_loss: 0.0019 - cl_head_accuracy: 1.0000 - bb_head_accuracy: 0.9250 - val_loss: 0.7841 - val_cl_head_loss: 0.7498 - val_bb_head_loss: 0.0343 - val_cl_head_accuracy: 0.8421 - val_bb_head_accuracy: 0.8421
# Epoch 20/20
# 20/20 [==============================] - 3s 162ms/step - loss: 0.0020 - cl_head_loss: 2.7592e-04 - bb_head_loss: 0.0017 - cl_head_accuracy: 1.0000 - bb_head_accuracy: 0.9375 - val_loss: 0.7797 - val_cl_head_loss: 0.7482 - val_bb_head_loss: 0.0315 - val_cl_head_accuracy: 0.8421 - val_bb_head_accuracy: 0.7368

# %%
predictions = model.predict(validation_images)
#print(predictions)

for nb_image in range(len(validation_images)):
    
    fig, ax = plt.subplots()


    img = Image.open(validation_filenames[nb_image]) # On ouvre l'image avec sa taille originale
    we, he = img.size  # largeur et hauteur de l'image initiale
    ax.imshow(img) # on affiche l'image
    

    box0 = predictions[0][nb_image] # les prédictions des classes
    box1 = predictions[1][nb_image] # les prédictions des boites
    
    # On repasse des coordonnées dans [0,1] aux coordonnées dans [largeur image, hauteur image] 
    xmin = box1[0] * we 
    ymin = box1[1] * he
    xmax = box1[2] * we 
    ymax = box1[3] * he
    
    w = abs(xmax-xmin) # largeur de la boite
    h = abs(ymax-ymin) # hauteur de la boite
    
    # determination de la categorie : 
    score = tf.nn.softmax(predictions[0][nb_image])
    percent = int(round(100*np.max(score), 0))
    title = "{}  {} %".format(categories[np.argmax(score)], percent) 

    print(title)

    ax.add_patch(Rectangle((xmin,ymin), w, h,linewidth=1,edgecolor='r',facecolor='none')) # le dessin de la boite
    
    plt.axis('off')  # si on veut enlever les graduations des axes
    plt.show()
# Out:
# with_mask  100 %
# with_mask  100 %
# with_mask  94 %
# with_mask  99 %
# with_mask  95 %
# with_mask  91 %
# with_mask  100 %
# with_mask  95 %
# with_mask  100 %
# without_mask  85 %
# without_mask  60 %
# without_mask  60 %
# with_mask  99 %
# without_mask  71 %
# without_mask  100 %
# without_mask  97 %
# without_mask  98 %
# with_mask  100 %
# without_mask  99 %
